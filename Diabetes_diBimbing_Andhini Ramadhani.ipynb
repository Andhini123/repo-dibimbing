# %%
import pandas as pd
data1 = pd.read_csv('/diabetes.csv')
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
from sklearn import datasets

# %%
#memuat dataset diabetes dari kaggle dan mengonversinya menjadi DataFrame
diabetes = datasets.load_digits()

# %%
X = diabetes.data #inputan untuk machine learning
y = diabetes.target #output yang dinginkan dari machine learning

# %%
# Mengonversi data fitur dan target menjadi DataFrame
df_X = pd.DataFrame(X, columns=diabetes.feature_names)
df_y = pd.Series(y, name='diabetes')

# %%
# Gabungkan fitur dan target dalam satu DataFrame
df = pd.concat([df_X, df_y], axis=1)

# %%
data =pd.read_csv('/diabetes.csv')

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
from sklearn.model_selection import train_test_split

#membagi data menjadi train dan test
X_train,_X_test, y_train, y_test=train_test_split(df_X, df_y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#membuat dan melatih model Decision Tree
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
# 4. Memprediksi dan mengevaluasi
y_pred = model.predict(_X_test)

accuracy = accuracy_score(y_test, y_pred)

print("laporan klasifikasi:")
print(f"akurasi: {accuracy * 100:2f}%")
# Out:
# laporan klasifikasi:
# akurasi: 84.166667%

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.plot([1,2,3,4], [2,4,6,8])
plt.ylabel('label Y')
plt.xlabel('label X')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.random.normal(size=100)
plt.hist(x, bins=10)
plt.show()

# %%
import pandas as pd

# %%
import numpy as np

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_cbb8e_row0_col0, #T_cbb8e_row1_col1, #T_cbb8e_row2_col2, #T_cbb8e_row3_col3, #T_cbb8e_row4_col4, #T_cbb8e_row5_col5, #T_cbb8e_row6_col6, #T_cbb8e_row7_col7, #T_cbb8e_row8_col8, #T_cbb8e_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cbb8e_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_cbb8e_row0_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_cbb8e_row0_col3, #T_cbb8e_row8_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_cbb8e_row0_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_cbb8e_row0_col5, #T_cbb8e_row0_col6, #T_cbb8e_row2_col3, #T_cbb8e_row2_col9, #T_cbb8e_row3_col2, #T_cbb8e_row4_col7, #T_cbb8e_row4_col8, #T_cbb8e_row6_col0, #T_cbb8e_row6_col1, #T_cbb8e_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cbb8e_row0_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_cbb8e_row0_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_cbb8e_row0_col9, #T_cbb8e_row5_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_cbb8e_row1_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_cbb8e_row1_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_cbb8e_row1_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_cbb8e_row1_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_cbb8e_row1_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_cbb8e_row1_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_cbb8e_row1_col7 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_cbb8e_row1_col8 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_cbb8e_row1_col9 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_cbb8e_row2_col0, #T_cbb8e_row3_col7, #T_cbb8e_row7_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_cbb8e_row2_col1, #T_cbb8e_row4_col1, #T_cbb8e_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_cbb8e_row2_col4, #T_cbb8e_row9_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_cbb8e_row2_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_cbb8e_row2_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_cbb8e_row2_col7, #T_cbb8e_row7_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_cbb8e_row2_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_cbb8e_row3_col0, #T_cbb8e_row3_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_cbb8e_row3_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_cbb8e_row3_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_cbb8e_row3_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_cbb8e_row3_col8 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_cbb8e_row3_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_cbb8e_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_cbb8e_row4_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_cbb8e_row4_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_cbb8e_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_cbb8e_row4_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_cbb8e_row4_col9, #T_cbb8e_row7_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_cbb8e_row5_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_cbb8e_row5_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_cbb8e_row5_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_cbb8e_row5_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_cbb8e_row5_col6, #T_cbb8e_row9_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_cbb8e_row5_col7, #T_cbb8e_row9_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_cbb8e_row5_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_cbb8e_row5_col9 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_cbb8e_row6_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_cbb8e_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_cbb8e_row6_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_cbb8e_row6_col5, #T_cbb8e_row8_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_cbb8e_row6_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_cbb8e_row6_col8, #T_cbb8e_row7_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_cbb8e_row6_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_cbb8e_row7_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_cbb8e_row7_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_cbb8e_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_cbb8e_row7_col9 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_cbb8e_row8_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_cbb8e_row8_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_cbb8e_row8_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_cbb8e_row8_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_cbb8e_row8_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_cbb8e_row8_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_cbb8e_row9_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_cbb8e_row9_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_cbb8e_row9_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_cbb8e_row9_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_cbb8e_row9_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_cbb8e_row9_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cbb8e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbb8e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cbb8e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cbb8e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cbb8e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cbb8e_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_cbb8e_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_cbb8e_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_cbb8e_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_cbb8e_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_cbb8e_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbb8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbb8e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cbb8e_row0_col1" class="data row0 col1" >0.347533</td>
#       <td id="T_cbb8e_row0_col2" class="data row0 col2" >0.398948</td>
#       <td id="T_cbb8e_row0_col3" class="data row0 col3" >0.455743</td>
#       <td id="T_cbb8e_row0_col4" class="data row0 col4" >0.072914</td>
#       <td id="T_cbb8e_row0_col5" class="data row0 col5" >-0.233402</td>
#       <td id="T_cbb8e_row0_col6" class="data row0 col6" >-0.731222</td>
#       <td id="T_cbb8e_row0_col7" class="data row0 col7" >0.477978</td>
#       <td id="T_cbb8e_row0_col8" class="data row0 col8" >-0.442621</td>
#       <td id="T_cbb8e_row0_col9" class="data row0 col9" >0.015185</td>
#     </tr>
#     <tr>
#       <th id="T_cbb8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbb8e_row1_col0" class="data row1 col0" >0.347533</td>
#       <td id="T_cbb8e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cbb8e_row1_col2" class="data row1 col2" >-0.284056</td>
#       <td id="T_cbb8e_row1_col3" class="data row1 col3" >0.571003</td>
#       <td id="T_cbb8e_row1_col4" class="data row1 col4" >-0.285483</td>
#       <td id="T_cbb8e_row1_col5" class="data row1 col5" >0.382480</td>
#       <td id="T_cbb8e_row1_col6" class="data row1 col6" >-0.362842</td>
#       <td id="T_cbb8e_row1_col7" class="data row1 col7" >0.642578</td>
#       <td id="T_cbb8e_row1_col8" class="data row1 col8" >0.252556</td>
#       <td id="T_cbb8e_row1_col9" class="data row1 col9" >0.190047</td>
#     </tr>
#     <tr>
#       <th id="T_cbb8e_level0_row2" class="row_heading level0

# %%
corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# <style type="text/css">
# #T_2c7a2_row0_col0, #T_2c7a2_row1_col1, #T_2c7a2_row2_col2, #T_2c7a2_row3_col3, #T_2c7a2_row4_col4, #T_2c7a2_row5_col5, #T_2c7a2_row6_col6, #T_2c7a2_row7_col7, #T_2c7a2_row8_col8, #T_2c7a2_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col3, #T_2c7a2_row8_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col5, #T_2c7a2_row0_col6, #T_2c7a2_row2_col3, #T_2c7a2_row2_col9, #T_2c7a2_row3_col2, #T_2c7a2_row4_col7, #T_2c7a2_row4_col8, #T_2c7a2_row6_col0, #T_2c7a2_row6_col1, #T_2c7a2_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row0_col9, #T_2c7a2_row5_col0 {
#   background-color: #9abbff;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col3 {
#   background-color: #f7a688;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col5 {
#   background-color: #dcdddd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col7 {
#   background-color: #f39475;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col8 {
#   background-color: #e6d7cf;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row1_col9 {
#   background-color: #c5d6f2;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col0, #T_2c7a2_row3_col7, #T_2c7a2_row7_col3 {
#   background-color: #f7bca1;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col1, #T_2c7a2_row4_col1, #T_2c7a2_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col4, #T_2c7a2_row9_col8 {
#   background-color: #d6dce4;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col6 {
#   background-color: #b6cefa;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col7, #T_2c7a2_row7_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row2_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col0, #T_2c7a2_row3_col1 {
#   background-color: #f7b194;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col4 {
#   background-color: #89acfd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col8 {
#   background-color: #ead5c9;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row3_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col6 {
#   background-color: #abc8fd;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row4_col9, #T_2c7a2_row7_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col2 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col6, #T_2c7a2_row9_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col7, #T_2c7a2_row9_col7 {
#   background-color: #f4c6af;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row5_col9 {
#   background-color: #aec9fc;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col2 {
#   background-color: #98b9ff;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col4 {
#   background-color: #9bbcff;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col5, #T_2c7a2_row8_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col8, #T_2c7a2_row7_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row6_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row7_col0 {
#   background-color: #f7ad90;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row7_col1 {
#   background-color: #f59f80;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row7_col9 {
#   background-color: #efcfbf;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col1 {
#   background-color: #cfdaea;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col7 {
#   background-color: #f1cdba;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row8_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col0 {
#   background-color: #cad8ef;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col4 {
#   background-color: #92b4fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col5 {
#   background-color: #93b5fe;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_2c7a2_row9_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# </style>
# <table id="T_2c7a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c7a2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2c7a2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2c7a2_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2c7a2_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2c7a2_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_2c7a2_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_2c7a2_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_2c7a2_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_2c7a2_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_2c7a2_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c7a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c7a2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2c7a2_row0_col1" class="data row0 col1" >0.347533</td>
#       <td id="T_2c7a2_row0_col2" class="data row0 col2" >0.398948</td>
#       <td id="T_2c7a2_row0_col3" class="data row0 col3" >0.455743</td>
#       <td id="T_2c7a2_row0_col4" class="data row0 col4" >0.072914</td>
#       <td id="T_2c7a2
